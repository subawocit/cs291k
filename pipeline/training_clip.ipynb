# %%
# %cd /hdd/yuchen/pipeline/training_pipeline
# Out:
# /hdd/yuchen/pipeline/training_pipeline

# %%
# !python train.py --data data_configs/sat_new.yaml --epochs 50 --imgsz 224 --device cuda:0 --use-train-aug False --model testfile --name sat_training --batch 2
# Out:
# Not using distributed mode
# device cuda:0
# Checking Labels and images...
# 100%|█████████████████████████████████████| 165/165 [00:00<00:00, 293993.27it/s]
# Checking Labels and images...
# 100%|███████████████████████████████████████| 33/33 [00:00<00:00, 314572.80it/s]
# Creating data loaders
# torch.Size([3, 224, 224])
# Number of training samples: 165
# Number of validation samples: 33
#
# Building model from scratch...
# ...
# Layer (type (var_name))                                           Input Shape               Output Shape              Param #
# ...
# FasterRCNN (FasterRCNN)                                           [2, 3, 224, 224]          [100, 4]                  --
# ├─GeneralizedRCNNTransform (transform)                            [2, 3, 224, 224]          [2, 3, 224, 224]          --
# ├─CustomCLIPModel (backbone)                                      [2, 3, 224, 224]          [2, 3, 16, 16]            --
# ...

# %%
# !python train.py --data data_configs/land4sensor.yaml --epochs 100 --use-train-aug False  --imgsz 224 --device cuda:0 --use-train-aug False --model fasterrcnn_clip --name land4sensor_training --batch 8
# Out:
# Not using distributed mode
# device cuda:0
# Checking Labels and images...
# 100%|████████████████████████████████████| 1440/1440 [00:00<00:00, 91071.91it/s]
# Checking Labels and images...
# 100%|█████████████████████████████████████| 309/309 [00:00<00:00, 230325.21it/s]
# Creating data loaders
# torch.Size([3, 224, 224])
# Number of training samples: 1440
# Number of validation samples: 309
#
# Building model from scratch...

# %%
# !python train.py --data data_configs/paper.yaml --epochs 50 --use-train-aug False  --imgsz 224 --device cuda:0 --model fasterrcnn_clip --name paper_training --batch 2
# Out:
# Traceback (most recent call last):
#   File "/hdd/yuchen/pipeline/training_pipeline/train.py", line 27, in <module>
#     from models.create_fasterrcnn_model import create_model
#   File "/hdd/yuchen/pipeline/training_pipeline/models/create_fasterrcnn_model.py", line 1, in <module>
#     from models import *
# AttributeError: module 'models' has no attribute 'testfile'
