# %%
# %cd /hdd/yuchen/pipeline/training_pipeline
# Out:
# /hdd/yuchen/pipeline/training_pipeline

# %%
# !python train.py --data data_configs/sat_new.yaml --epochs 50 --imgsz 224 --device cuda:0 --model fasterrcnn_vitdet --name sat_training --batch 8
# Out:
# Not using distributed mode
# device cuda:0
# Checking Labels and images...
# 100%|█████████████████████████████████████| 165/165 [00:00<00:00, 296766.79it/s]
# Checking Labels and images...
# 100%|███████████████████████████████████████| 33/33 [00:00<00:00, 317458.79it/s]
# Creating data loaders
# torch.Size([3, 224, 224])
# Number of training samples: 165
# Number of validation samples: 33
#
# Building model from scratch...
# Loading MAE Pretrained ViT Base weights...
# ...
# Layer (type (var_name))                            Input Shape               Output Shape              Param #
# ...
# FasterRCNN (FasterRCNN)                            [1, 3, 224, 224]          [100, 4]                  --
# ├─GeneralizedRCNNTransform (transform)             [1, 3, 224, 224]          [1, 3, 224, 224]          --
# ├─SimpleFeaturePyramid (backbone)                  [1, 3, 224, 224]          [1, 256, 4, 4]            --
# ...

# %%
# !python train.py --data data_configs/sat_new.yaml --epochs 50 --imgsz 224 --device cuda:0 --model fasterrcnn_resnet50_fpn --name sat_training --batch 8
# Out:
# Not using distributed mode
# device cuda:0
# Checking Labels and images...
# 100%|█████████████████████████████████████| 165/165 [00:00<00:00, 256223.68it/s]
# Checking Labels and images...
# 100%|███████████████████████████████████████| 33/33 [00:00<00:00, 284798.42it/s]
# Creating data loaders
# torch.Size([3, 224, 224])
# Number of training samples: 165
# Number of validation samples: 33
#
# Building model from scratch...
# ^C
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(224,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# ...

# %%
# !python train.py --data data_configs/land4sensor.yaml --epochs 50 --imgsz 224 --device cuda:0 --model fasterrcnn_resnet50_fpn --name land4sensor_training --batch 8
# Out:
# Not using distributed mode
# device cuda:0
# Checking Labels and images...
# 100%|████████████████████████████████████| 1440/1440 [00:00<00:00, 97314.07it/s]
# Checking Labels and images...
# 100%|█████████████████████████████████████| 309/309 [00:00<00:00, 246817.74it/s]
# Creating data loaders
# torch.Size([3, 224, 224])
# Number of training samples: 1440
# Number of validation samples: 309
#
# Building model from scratch...
# ...
# Layer (type (var_name))                                 Input Shape               Output Shape              Param #
# ...
# FasterRCNN (FasterRCNN)                                 [8, 3, 224, 224]          [100, 4]                  --
# ├─GeneralizedRCNNTransform (transform)                  [8, 3, 224, 224]          [8, 3, 224, 224]          --
# ├─BackboneWithFPN (backbone)                            [8, 3, 224, 224]          [8, 256, 4, 4]            --
# ...

# %%
# !python train.py --data data_configs/land4sensor.yaml --epochs 90 --imgsz 224 --device cuda:0 --model fasterrcnn_vitdet --name land4sensor_training --batch 2
# Out:
# Not using distributed mode
# device cuda:0
# Checking Labels and images...
# 100%|████████████████████████████████████| 1440/1440 [00:00<00:00, 91766.53it/s]
# Checking Labels and images...
# 100%|█████████████████████████████████████| 309/309 [00:00<00:00, 223032.17it/s]
# Creating data loaders
# torch.Size([3, 224, 224])
# Number of training samples: 1440
# Number of validation samples: 309
#
# Building model from scratch...
# Loading MAE Pretrained ViT Base weights...
# ...
# Layer (type (var_name))                            Input Shape               Output Shape              Param #
# ...
# FasterRCNN (FasterRCNN)                            [2, 3, 224, 224]          [100, 4]                  --
# ├─GeneralizedRCNNTransform (transform)             [2, 3, 224, 224]          [2, 3, 224, 224]          --
# ├─SimpleFeaturePyramid (backbone)                  [2, 3, 224, 224]          [2, 256, 4, 4]            --
# ...

# %%
# !python inference.py --input /hdd/yuchen/pipeline/training_pipeline/data_land4sensor/valid --data data_configs/land4sensor.yaml --weights outputs/training/land4sensor_training/best_model.pth --imgsz 224 --device cuda:0 --threshold 0.8 --model fasterrcnn_vitdet --save_img True

# %%
# !python eval.py --data data_configs/land4sensor.yaml --weights outputs/training/land4sensor_training/best_model.pth --imgsz 224 --device cuda:0  --model fasterrcnn_resnet50_fpn
# Out:
# Checking Labels and images...
# ...
# 100%|███████████████████████████████████████████| 39/39 [00:08<00:00,  4.44it/s]
#
#
# {'classes': tensor(1, dtype=torch.int32),
#  'map': tensor(0.0780),
#  'map_50': tensor(0.2133),
#  'map_75': tensor(0.0358),
#  'map_large': tensor(0.2098),
#  'map_medium': tensor(0.1510),
#  'map_per_class': tensor(-1.),
#  'map_small': tensor(0.0718),
#  'mar_1': tensor(0.0501),
#  'mar_10': tensor(0.1842),
#  'mar_100': tensor(0.3410),
#  'mar_100_per_class': tensor(-1.),
#  'mar_large': tensor(0.4632),
#  'mar_medium': tensor(0.4102),
#  'mar_small': tensor(0.3180)}

# %% [markdown]
# ## paper dataset

# %%
# !python train.py --data data_configs/paper.yaml --epochs 50 --imgsz 224 --device cuda:0 --model fasterrcnn_resnet50_fpn --name paper_training --batch 8
