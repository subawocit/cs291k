# %%
# %cd /hdd/yuchen/pipeline/training_pipeline
# Out:
# /hdd/yuchen/pipeline/training_pipeline

# %%
# !python train.py --data data_configs/sat.yaml --epochs 20 --imgsz 640 --device cuda:0 --model fasterrcnn_vitdet --name sat_training --batch 2

# %%
# !python train.py --data data_configs/sat.yaml --epochs 50 --imgsz 640 --device cuda:0 --model fasterrcnn_resnet50_fpn --name sat_training --batch 8
# Out:
# Not using distributed mode
# device cuda:0
# Checking Labels and images...
# 100%|█████████████████████████████████████| 174/174 [00:00<00:00, 248318.78it/s]
# Checking Labels and images...
# 100%|███████████████████████████████████████| 22/22 [00:00<00:00, 266689.85it/s]
# Creating data loaders
# torch.Size([3, 640, 640])
# Number of training samples: 174
# Number of validation samples: 22
#
# Building model from scratch...
# ...
# Layer (type (var_name))                                 Input Shape               Output Shape              Param #
# ...
# FasterRCNN (FasterRCNN)                                 [8, 3, 640, 640]          [100, 4]                  --
# ├─GeneralizedRCNNTransform (transform)                  [8, 3, 640, 640]          [8, 3, 640, 640]          --
# ├─BackboneWithFPN (backbone)                            [8, 3, 640, 640]          [8, 256, 10, 10]          --
# ...

# %%
# !python inference.py --input /hdd/yuchen/pipeline/training_pipeline/sat_data/valid --data data_configs/sat.yaml --weights outputs/training/sat_training/best_model.pth --imgsz 640 --device cuda:0 --model fasterrcnn_vitdet --save_img True
# Out:
# Building from model name arguments...
# Loading MAE Pretrained ViT Base weights...
# Test instances: 22
# Checking Labels and images...
# 100%|███████████████████████████████████████| 22/22 [00:00<00:00, 210672.80it/s]
# creating index...
# index created!
# Averaged stats: model_time: 0.0681 (0.1672)  evaluator_time: 0.0013 (0.0021)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
# ...
